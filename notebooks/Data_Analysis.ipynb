# %% [markdown]
# <a href="https://colab.research.google.com/github/ExcessGroups/Earthquake_EDA/blob/main/notebooks/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %%
ls -l
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data/

# %%
# !ll
# Out:
# /bin/bash: line 1: ll: command not found

# %%
# !ll -ls
# Out:
# /bin/bash: line 1: ll: command not found

# %%
# !du -sh
# Out:
# 55M	.

# %%
# !du -h
# Out:
# 8.0K	./.config/configurations
# 88K	./.config/logs/2026.06.04
# 92K	./.config/logs
# 148K	./.config
# 55M	./sample_data
# 55M	.

# %%
# !mkdir Data_Analysis

# %%
# %cd Data_Analysis
# Out:
# /content/Data_Analysis

# %%
# !mkdir Data Notebooks Figures Scripts

# %%
import pandas as pd

earthquakes = {"magnitude": [3.2, 4.1, 2.8, 5.0, 3.7],
               "Depth": [12, 8, 20, 5, 15],
               "Station": ["AB01", "AB02", "AB01", "AB03", "AB02"],
               "Country": ["Nigeria", "Nigeria", "Cameroon", "Nigeria", "Ghana"]
}


df = pd.DataFrame(earthquakes)
df
# Out:
#    magnitude  Depth Station   Country
# 0        3.2     12    AB01   Nigeria
# 1        4.1      8    AB02   Nigeria
# 2        2.8     20    AB01  Cameroon
# 3        5.0      5    AB03   Nigeria
# 4        3.7     15    AB02     Ghana

# %%
df.columns
# Out:
# Index(['magnitude', 'Depth', 'Station', 'Country'], dtype='object')

# %%
df.shape
# Out:
# (5, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   magnitude  5 non-null      float64
#  1   Depth      5 non-null      int64
#  2   Station    5 non-null      object
#  3   Country    5 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
df.dtypes
# Out:
# magnitude    float64
# Depth          int64
# Station       object
# Country       object
# dtype: object

# %%
df['magnitude']
# Out:
# 0    3.2
# 1    4.1
# 2    2.8
# 3    5.0
# 4    3.7
# Name: magnitude, dtype: float64

# %%
df[['magnitude']]
# Out:
#    magnitude
# 0        3.2
# 1        4.1
# 2        2.8
# 3        5.0
# 4        3.7

# %%
df.loc[0]
# Out:
# magnitude        3.2
# Depth             12
# Station         AB01
# Country      Nigeria
# Name: 0, dtype: object

# %%
df.loc[:2]
# Out:
#    magnitude  Depth Station   Country
# 0        3.2     12    AB01   Nigeria
# 1        4.1      8    AB02   Nigeria
# 2        2.8     20    AB01  Cameroon

# %%
df.loc[0:1, ['magnitude', 'Station']]
# Out:
#    magnitude Station
# 0        3.2    AB01
# 1        4.1    AB02

# %%
df[["magnitude", "Station"]]
# Out:
#    magnitude Station
# 0        3.2    AB01
# 1        4.1    AB02
# 2        2.8    AB01
# 3        5.0    AB03
# 4        3.7    AB02

# %%
df.loc[:3]
# Out:
#    magnitude  Depth Station   Country
# 0        3.2     12    AB01   Nigeria
# 1        4.1      8    AB02   Nigeria
# 2        2.8     20    AB01  Cameroon
# 3        5.0      5    AB03   Nigeria

# %%
df['Station'].dtype
# Out:
# dtype('O')

# %%
mask= df['magnitude'] > 4

# %%
df[mask]
# Out:
#    magnitude  Depth Station  Country
# 1        4.1      8    AB02  Nigeria
# 3        5.0      5    AB03  Nigeria

# %%
df[df['Country'] == 'Nigeria']
# Out:
#    magnitude  Depth Station  Country
# 0        3.2     12    AB01  Nigeria
# 1        4.1      8    AB02  Nigeria
# 3        5.0      5    AB03  Nigeria

# %%
df[df['Country'] != 'Nigeria']
# Out:
#    magnitude  Depth Station   Country
# 2        2.8     20    AB01  Cameroon
# 4        3.7     15    AB02     Ghana

# %%
df[df['Depth'] >= 15]
# Out:
#    magnitude  Depth Station   Country
# 2        2.8     20    AB01  Cameroon
# 4        3.7     15    AB02     Ghana

# %%
df[(df['Country'] =='Nigeria') & (df['magnitude'] > 4)]
# Out:
#    magnitude  Depth Station  Country
# 1        4.1      8    AB02  Nigeria
# 3        5.0      5    AB03  Nigeria

# %%
df[(df['Country'] == 'Nigeria') | (df['Country'] == 'Cameroon')]
# Out:
#    magnitude  Depth Station   Country
# 0        3.2     12    AB01   Nigeria
# 1        4.1      8    AB02   Nigeria
# 2        2.8     20    AB01  Cameroon
# 3        5.0      5    AB03   Nigeria

# %%
df[df['Station'] == 'AB01']
# Out:
#    magnitude  Depth Station   Country
# 0        3.2     12    AB01   Nigeria
# 2        2.8     20    AB01  Cameroon

# %%
df[(df['Country'] == 'Cameroon') | (df['Country'] == 'Ghana')]
# Out:
#    magnitude  Depth Station   Country
# 2        2.8     20    AB01  Cameroon
# 4        3.7     15    AB02     Ghana

# %%
df[(df['Country'] == 'Nigeria') & (df['Depth'] <= 10)]
# Out:
#    magnitude  Depth Station  Country
# 1        4.1      8    AB02  Nigeria
# 3        5.0      5    AB03  Nigeria

# %%
df.describe()
# Out:
#        magnitude     Depth
# count   5.000000   5.00000
# mean    3.760000  12.00000
# std     0.850294   5.87367
# min     2.800000   5.00000
# 25%     3.200000   8.00000
# 50%     3.700000  12.00000
# 75%     4.100000  15.00000
# max     5.000000  20.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   magnitude  5 non-null      float64
#  1   Depth      5 non-null      int64
#  2   Station    5 non-null      object
#  3   Country    5 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
df.columns
# Out:
# Index(['magnitude', 'Depth', 'Station', 'Country'], dtype='object')

# %%
df['Country'].unique()
# Out:
# array(['Nigeria', 'Cameroon', 'Ghana'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# Country
# Nigeria     3
# Cameroon    1
# Ghana       1
# Name: count, dtype: int64

# %%
df['Station'].value_counts()
# Out:
# Station
# AB01    2
# AB02    2
# AB03    1
# Name: count, dtype: int64

# %%
df.groupby('Country')['magnitude'].mean()
# Out:
# Country
# Cameroon    2.8
# Ghana       3.7
# Nigeria     4.1
# Name: magnitude, dtype: float64

# %%
df.groupby('Country').size()
# Out:
# Country
# Cameroon    1
# Ghana       1
# Nigeria     3
# dtype: int64

# %%
df.groupby('Country')['Depth'].max()
# Out:
# Country
# Cameroon    20
# Ghana       15
# Nigeria     12
# Name: Depth, dtype: int64

# %%
df.groupby('Country')['magnitude'].agg(['mean', 'max', 'min'])
# Out:
#           mean  max  min
# Country
# Cameroon   2.8  2.8  2.8
# Ghana      3.7  3.7  3.7
# Nigeria    4.1  5.0  3.2

# %%
df.groupby(['Country', 'Station']).size()
# Out:
# Country   Station
# Cameroon  AB01       1
# Ghana     AB02       1
# Nigeria   AB01       1
#           AB02       1
#           AB03       1
# dtype: int64

# %%
df.groupby('Country')['Depth'].mean()
# Out:
# Country
# Cameroon    20.000000
# Ghana       15.000000
# Nigeria      8.333333
# Name: Depth, dtype: float64

# %%
df.groupby('Country')['magnitude'].mean()
# Out:
# Country
# Cameroon    2.8
# Ghana       3.7
# Nigeria     4.1
# Name: magnitude, dtype: float64

# %%
df.groupby('Country')['magnitude'].agg(['mean','max','min', 'count'])
# Out:
#           mean  max  min  count
# Country
# Cameroon   2.8  2.8  2.8      1
# Ghana      3.7  3.7  3.7      1
# Nigeria    4.1  5.0  3.2      3

# %%
# !mkdir -p 'data/raw'

# %%
# !mkdir -p Earthquake_EDA/{data/raw,data/processed,notebooks,figures,outputs}

# %%
# !find Earthquake_EDA
# Out:
# Earthquake_EDA
# Earthquake_EDA/outputs
# Earthquake_EDA/data
# Earthquake_EDA/data/processed
# Earthquake_EDA/data/raw
# Earthquake_EDA/figures
# Earthquake_EDA/notebooks

# %%
# !tree
# Out:
# /bin/bash: line 1: tree: command not found

# %%
# !apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 3 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 1s (48.7 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 118243 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tree
# Out:
# .
# ├── data
# │   ├── processed
# │   └── raw
# │       └── events.csv
# ├── Earthquake_EDA
# │   ├── data
# │   │   ├── processed
# │   │   └── raw
# │   ├── figures
# │   ├── notebooks
# │   └── outputs
# └── sample_data
#     ├── anscombe.json
#     ├── california_housing_test.csv
#     ├── california_housing_train.csv
#     ├── mnist_test.csv
#     ├── mnist_train_small.csv
#     └── README.md
#
# 11 directories, 7 files

# %%
import os

os.listdir('./data/')
# Out:
# ['processed', 'raw', '.ipynb_checkpoints']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
